# %%
# !pip install -q -U google-genai

# %%
import os
os.environ['GEMINI_API_KEY'] = 'AIzaSyBROS51U3M7iHTIlxMuP2YO7q2vcc70uBY'

# %%
from google import genai
from google.genai import types

client = genai.Client()

response = client.models.generate_content(
    model = 'gemini-2.5-flash-lite',
    contents = 'Explain how ai works?'
)
print(response)
# Out:
# sdk_http_response=HttpResponse(
#   headers=<dict len=12>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""The term "AI" (Artificial Intelligence) is quite broad, but at its core, it's about **creating systems that can perform tasks that typically require human intelligence.** This includes things like learning, problem-solving, decision-making, understanding language, and recognizing patterns.
#
# Instead of being programmed with explicit instructions for every single scenario, AI systems are designed to **learn and adapt.** Here's a breakdown of how it generally works, focusing on the most common and impactful types of AI today:
#
# **1. Data is the Fuel:**
#
# * **Vast Amounts of Information:** AI systems are trained on enormous datasets. This data can be anything from text, images, audio, videos, numbers, sensor readings, and more.
# * **The Quality Matters:** The accuracy and relevance of the data are crucial. "Garbage in, garbage out" is a common saying in AI. If the data is biased, incorrect, or incomplete, the AI will learn those flaws.
#
# **2. Algorithms: The Brains of the Operation:**
#
# * **Mathematical Models:** AI uses complex mathematical algorithms and statistical models. These algorithms define how the AI will process the data, identify patterns, and make decisions.
# * **Learning from Experience:** The key difference from traditional programming is that these algorithms aren't just following rigid rules. They are designed to adjust their internal parameters based on the data they process.
#
# **3. Key AI Techniques and Concepts:**
#
# * **Machine Learning (ML): The Most Dominant Form of AI**
#     * **Supervised Learning:** This is like teaching a child with flashcards. The AI is given labeled data (e.g., images of cats labeled "cat," images of dogs labeled "dog"). It learns to associate the features of the input with the correct output.
#         * **Examples:** Image recognition, spam filters, predicting housing prices.
#     * **Unsupervised Learning:** Here, the AI is given unlabeled data and asked to find patterns or structures on its own. It's like giving someone a box of LEGOs and asking them to sort them by color or shape.
#         * **Examples:** Clustering customers into different segments, anomaly detection, dimensionality reduction.
#     * **Reinforcement Learning:** This is like training a pet with rewards and punishments. The AI learns by trial and error, receiving "rewards" for desired actions and "penalties" for undesired ones. It aims to maximize its cumulative reward over time.
#         * **Examples:** Game playing (AlphaGo), robotics, autonomous driving.
#
# * **Deep Learning (DL): A Subset of ML**
#     * **Neural Networks:** Deep learning uses artificial neural networks, which are inspired by the structure and function of the human brain. These networks have multiple layers (hence "deep") that process information in stages.
#     * **Feature Extraction:** Each layer in a neural network learns to extract increasingly complex features from the data. For example, in image recognition, early layers might detect edges and corners, while later layers recognize more complex shapes and objects.
#     * **Examples:** Advanced image and speech recognition, natural language processing (like the one you're interacting with), self-driving cars.
#
# * **Natural Language Processing (NLP): Understanding Human Language**
#     * **Text and Speech:** NLP allows AI to understand, interpret, and generate human language.
#     * **Key Tasks:**
#         * **Tokenization:** Breaking down text into words or sub-word units.
#         * **Part-of-Speech Tagging:** Identifying the grammatical role of words.
#         * **Named Entity Recognition:** Identifying names of people, places, organizations, etc.
#         * **Sentiment Analysis:** Determining the emotional tone of text.
#         * **Machine Translation:** Translating text from one language to another.
#         * **Text Generation:** Creating human-like text.
#
# **4. The Learning Process (Simplified):**
#
# * **Training:** The AI is fed its data. The algorithms adjust their internal parameters (weights and biases in neural networks) to minimize errors in predictions or to find desired patterns.
# * **Testing:** Once trained, the AI is presented with new, unseen data to evaluate its performance and see how well it generalizes.
# * **Inference/Prediction:** After successful training and testing, the AI can be deployed to make predictions or decisions on real-world data.
#
# **Analogy:**
#
# Imagine you want to teach an AI to recognize cats.
#
# 1.  **Data:** You show it thousands of pictures, some with cats, some without, and label them accordingly.
# 2.  **Algorithm (Neural Network):** You use a deep learning algorithm that's like a series of filters.
# 3.  **Training:** The AI looks at a picture. The first filter might detect lines and curves. The next filter combines those into simple shapes. Subsequent filters combine shapes into more complex features like ears, eyes, and whiskers. The AI adjusts how it weighs these features to get closer to correctly identifying "cat."
# 4.  **Testing:** You show it a new picture it's never seen before.
# 5.  **Prediction:** If it has learned well, it will correctly identify the cat.
#
# **In Summary:**
#
# AI works by **learning from data** using **complex algorithms**. Machine learning, especially deep learning, is the most prevalent approach, enabling AI systems to identify patterns, make predictions, and perform tasks that were once exclusively the domain of human intelligence. The more data and the better the algorithms, the more capable the AI becomes."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash-lite' prompt_feedback=None response_id='Ph_iaZatIpOsg8UPiY6U4Qo' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=1148,
#   prompt_token_count=6,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=6
#     ),
#   ],
#   total_token_count=1154
# ) model_status=None automatic_function_calling_history=[] parsed=None
