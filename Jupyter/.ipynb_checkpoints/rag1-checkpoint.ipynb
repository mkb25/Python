# %%
# %pip install -q -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -q -U ipywidgets
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Save the list of files to a Python list
files = !ls
print(files)
# Out:
# ['docs', 'myenv', 'rag1.ipynb', 'requirements.txt', 'vector_db']

# %%
from langchain_community.document_loaders import DirectoryLoader, UnstructuredFileLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma

# %%
import sys
import os

os.environ["HF_TOKEN"] = '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'
print(f"Jupyter is looking in: {sys.executable}")
print(f"Search paths: {sys.path}")
# Out:
# Jupyter is looking in: /home/costrategix/.local/share/pipx/venvs/jupyterlab/bin/python
# Search paths: ['/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/home/costrategix/.local/share/pipx/venvs/jupyterlab/lib/python3.12/site-packages', '/home/costrategix/.local/share/pipx/shared/lib/python3.12/site-packages']

# %%
import nltk

nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/costrategix/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# !pwd
# Out:
# /home/costrategix/MyDir/Python/RAG

# %%
docs_dir_path = '/home/costrategix/MyDir/Python/RAG/docs'
vector_db_path = '/home/costrategix/MyDir/Python/RAG/vector_db'
collection_name = 'doc_collection'

# %%
#loading the embedding model

embedding = HuggingFaceEmbeddings()
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# MPNetModel LOAD REPORT from: sentence-transformers/all-mpnet-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# directory loader
loader = DirectoryLoader(
    path=docs_dir_path,
    glob="./*.pdf",
    loader_cls=UnstructuredFileLoader
)

# single file can also be loaded with UnstructuredFileLoader

# %%
# load the documents
documents = loader.load()
# Out:
# No languages specified, defaulting to English.
# No languages specified, defaulting to English.

# %%
print(type(documents))
# print(documents[0])
# Out:
# <class 'list'>

# %%
# initializing the text splitter
text_splitter = CharacterTextSplitter(
    chunk_size=2000,
    chunk_overlap=500
)

# %%
# splitting the text into smaller chunks
text_chunks = text_splitter.split_documents(documents)
# Out:
# Created a chunk of size 3183, which is longer than the specified 2000

# %%
len(text_chunks)
# Out:
# 35

# %%
# creating the vector store
vector_store = Chroma.from_documents(
    documents=text_chunks,
    embedding=embedding,
    persist_directory=vector_db_path,
    collection_name=collection_name
)
