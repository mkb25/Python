# %%
import os

from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_groq import ChatGroq
# langchain library has been restructured recently. Use langchain_classic for older imports as mentioned below.
from langchain_classic.chains import RetrievalQA

# %%
os.environ['GROQ_API_KEY'] = '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'
os.environ["HF_TOKEN"] = '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'

# %%
# configuration
vector_db_path = '/home/costrategix/MyDir/Python/RAG/vector_db'
collection_name = 'doc_collection'

# %%
# loading the embedding model - default model
embedding = HuggingFaceEmbeddings()
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# MPNetModel LOAD REPORT from: sentence-transformers/all-mpnet-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# initialize groq llm
llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.0
)

# %%
vector_store = Chroma(
    collection_name=collection_name,
    embedding_function=embedding,
    persist_directory=vector_db_path
)

# %%
retriever = vector_store.as_retriever()

# %%
test_vector = embedding.embed_query("Is this model working?")
print(f"Vector length: {len(test_vector)}")
print(f"Sample values: {test_vector[:5]}")
# Out:
# Vector length: 768
# Sample values: [0.01861739158630371, 0.024399831891059875, 0.019354745745658875, 0.06129784137010574, -0.01254341471940279]

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    return_source_documents=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 qa_chain = RetrievalQA.from_chain_type(
#       2     llm=llm,
#       3     chain_type="stuff",
#       4     retriever=retriever,
#
# NameError: name 'RetrievalQA' is not defined

# %%
query = "What is Energy Flow?"
response = qa_chain.invoke({"query":query})
print(response["result"],'\n')
print("*-*-"*20,'\n')
for source in response["source_documents"]:
    print(source.metadata)
# Out:
# Energy flow refers to the movement of energy through an ecosystem, from one trophic level to the next, from producers to consumers. It is the process by which energy is transferred from one organism to another through the food chain or food web.
#
# In an ecosystem, energy flows from the sun to the producers (plants and autotrophic bacteria), which capture the energy through photosynthesis. This energy is then transferred to the primary consumers (herbivores), which eat the producers. The energy is then passed on to the secondary consumers (carnivores), which eat the primary consumers, and so on.
#
# Energy flow is unidirectional, meaning that energy cannot be transferred back to the previous trophic level. At each trophic level, some energy is lost as heat, and some is used for metabolic processes, leaving only a small amount of energy available for the next trophic level.
#
# The energy flow through an ecosystem is typically depicted as a pyramid, with the producers at the base and the top predators at the apex. The pyramid shows that as energy moves from one trophic level to the next, the amount of energy available decreases, resulting in a narrow base and a wide top.
#
# Energy flow is an essential component of ecosystem function, as it supports the growth and survival of organisms and maintains the structure and diversity of the ecosystem.
#
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
#
# {'source': '/home/costrategix/MyDir/Python/RAG/docs/12. Ecosystem.pdf'}
# {'source': '/home/costrategix/MyDir/Python/RAG/docs/12. Ecosystem.pdf'}
# {'source': '/home/costrategix/MyDir/Python/RAG/docs/12. Ecosystem.pdf'}
# {'source': '/home/costrategix/MyDir/Python/RAG/docs/12. Ecosystem.pdf'}

# %%
query = "What does the document say about Evolution and Ecosystem?"
response = qa_chain.invoke({"query":query})
print(response["result"])
print("-"*50)
for source in response["source_documents"]:
    print(source.metadata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 query = "What does the document say about Evolution and Ecosystem?"
# ----> 2 response = qa_chain.invoke({"query":query})
#       3 print(response["result"])
#       4 print("-"*50)
#       5 for source in response["source_documents"]:
#
# NameError: name 'qa_chain' is not defined
